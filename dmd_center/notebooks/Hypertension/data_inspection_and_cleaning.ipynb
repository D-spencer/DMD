# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../../data/cardio_data_processed.csv")
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years        bmi           bp_category  \
# 0     0       1       0         50  21.967120  Hypertension Stage 1
# 1     0       1       1         55  34.927679  Hypertension Stage 2
# 2     0       0       1         51  23.507805  Hypertension Stage 1
# 3     0       1       1         48  28.710479  Hypertension Stage 2
# 4     0       0       0         47  23.011177                Normal
#
#     bp_category_encoded
# 0  Hypertension Stage 1
# 1  Hypertension Stage 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   68205 non-null  int64
#  1   age                  68205 non-null  int64
#  2   gender               68205 non-null  int64
#  3   height               68205 non-null  int64
#  4   weight               68205 non-null  float64
#  5   ap_hi                68205 non-null  int64
#  6   ap_lo                68205 non-null  int64
#  7   cholesterol          68205 non-null  int64
#  8   gluc                 68205 non-null  int64
#  9   smoke                68205 non-null  int64
#  10  alco                 68205 non-null  int64
#  11  active               68205 non-null  int64
#  12  cardio               68205 non-null  int64
#  13  age_years            68205 non-null  int64
#  14  bmi                  68205 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                     0
# age                    0
# gender                 0
# height                 0
# weight                 0
# ap_hi                  0
# ap_lo                  0
# cholesterol            0
# gluc                   0
# smoke                  0
# alco                   0
# active                 0
# cardio                 0
# age_years              0
# bmi                    0
# bp_category            0
# bp_category_encoded    0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                   id           age        gender        height        weight  \
# count   68205.000000  68205.000000  68205.000000  68205.000000  68205.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    49972.410498  19462.667737      1.348625    164.372861     74.100688
# std     28852.138290   2468.381854      0.476539      8.176756     14.288862
# min         0.000000  10798.000000      1.000000     55.000000     11.000000
# 25%     24991.000000  17656.000000      1.000000    159.000000     65.000000
# 50%     50008.000000  19700.000000      1.000000    165.000000     72.000000
# 75%     74878.000000  21323.000000      2.000000    170.000000     82.000000
# max     99999.000000  23713.000000      2.000000    250.000000    200.000000
#
# ...

# %% [markdown]
# ### Drop Unncessary column

# %%
df.drop(columns=["age", 'id'],inplace=True )

# %%
df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age_years        bmi           bp_category  \
# 0       1       0         50  21.967120  Hypertension Stage 1
# 1       1       1         55  34.927679  Hypertension Stage 2
# 2       0       1         51  23.507805  Hypertension Stage 1
# 3       1       1         48  28.710479  Hypertension Stage 2
# 4       0       0         47  23.011177                Normal
#
#     bp_category_encoded
# 0  Hypertension Stage 1
# 1  Hypertension Stage 2
# 2  Hypertension Stage 1
# 3  Hypertension Stage 2
# 4                Normal

# %% [markdown]
# ### Gender

# %%
df["gender"] = df['gender'].replace(1,"F").replace(2,"M")

# %%
df["gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df["gender"].value_counts()
# Out:
# gender
# F    44427
# M    23778
# Name: count, dtype: int64

# %%
df["gender"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Height

# %%
df["height"].unique()
# Out:
# array([168, 156, 165, 169, 151, 157, 178, 158, 164, 173, 181, 172, 170,
#        154, 162, 163, 153, 159, 166, 155, 160, 175, 171, 152, 187, 148,
#        179, 180, 188, 185, 167, 183, 174, 176, 161, 184, 177, 182,  76,
#        149, 142, 150, 144, 186, 147, 146, 141, 195, 140, 198, 145, 143,
#        196, 138, 194, 190, 134, 136, 100, 120, 189, 137, 192, 122, 250,
#        191, 117,  97, 119, 130, 110, 193,  75, 132,  71, 135,  67,  70,
#        125, 139, 133,  74, 112, 207,  68,  55,  81,  80,  64,  91,  60,
#        109,  72, 197,  65, 128, 105, 108, 111, 113,  96, 104, 131,  59,
#         99,  57])

# %%
df["height"].value_counts()
# Out:
# height
# 165    5728
# 160    4890
# 170    4584
# 168    4307
# 164    3323
#        ...
# 104       1
# 131       1
# 59        1
# 99        1
# 57        1
# Name: count, Length: 106, dtype: int64

# %%
df["height"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### weight

# %%
df["weight"].unique()
# Out:
# array([ 62.  ,  85.  ,  64.  ,  82.  ,  56.  ,  67.  ,  93.  ,  95.  ,
#         71.  ,  68.  ,  80.  ,  60.  ,  78.  , 112.  ,  75.  ,  52.  ,
#         83.  ,  69.  ,  90.  ,  45.  ,  65.  ,  59.  ,  66.  ,  74.  ,
#        105.  ,  73.  ,  55.  ,  70.  ,  72.  ,  63.  ,  50.  , 107.  ,
#         84.  ,  77.  ,  79.  ,  76.  ,  58.  , 115.  ,  97.  ,  53.  ,
#         57.  ,  49.  , 110.  ,  94.  ,  92.  ,  87.  , 103.  ,  88.  ,
#         99.  , 100.  ,  61.  ,  48.  ,  54.  ,  51.  ,  47.  ,  91.  ,
#        104.  ,  81.  ,  98.  , 108.  ,  89.  , 101.  ,  86.  ,  65.5 ,
#        142.  ,  96.  ,  44.  , 169.  , 116.  , 200.  ,  64.8 , 120.  ,
#        117.  , 125.  , 106.  , 114.  , 113.  , 129.  , 124.  ,  42.  ,
#        123.  , 111.  , 102.  , 109.  ,  46.  , 139.  , 150.  , 138.  ,
#        131.  ,  43.  ,  83.6 , 134.  , 106.5 , 121.  ,  40.  , 141.  ,
#        119.  , 126.  , 177.  , 165.  , 122.  ,  41.  ,  62.3 , 118.  ,
# ...

# %%
df["weight"].isna().sum()
# Out:
# np.int64(0)

# %%
df["weight"].value_counts()
# Out:
# weight
# 65.0     3779
# 70.0     3692
# 68.0     2767
# 75.0     2675
# 60.0     2670
#          ...
# 67.3        1
# 94.7        1
# 147.0       1
# 55.4        1
# 99.9        1
# Name: count, Length: 278, dtype: int64

# %% [markdown]
# ### Ap_hi

# %%
df["ap_hi"].unique()
# Out:
# array([110, 140, 130, 150, 100, 120, 145, 170, 135, 125,  90, 180, 160,
#        133, 122, 169, 126, 158, 123, 161, 147, 115, 137, 153, 148, 105,
#        119, 141, 165, 164, 124, 172, 162, 117, 134, 166, 176, 116, 121,
#        112, 113, 118, 155, 142, 157, 136, 146, 138, 131, 159, 109, 106,
#        129,  93, 179,  95, 156, 168, 132, 104, 103, 175, 128, 151, 139,
#        127, 108, 144, 102, 143, 107, 178, 149, 167, 114, 101, 171, 111,
#        163, 154, 177, 174, 152,  96, 173,  99])

# %%
df["ap_hi"].value_counts()
# Out:
# ap_hi
# 120    27654
# 140     9324
# 130     8907
# 110     8617
# 150     4197
#        ...
# 178        2
# 96         2
# 177        2
# 173        2
# 93         1
# Name: count, Length: 86, dtype: int64

# %% [markdown]
# Ap_lo

# %%
df["ap_lo"].unique()
# Out:
# array([ 80,  90,  70, 100,  60,  85,  89, 110,  65,  63,  79, 120, 109,
#         84,  91,  73,  78,  75,  86,  87,  82,  95,  69,  74,  97,  81,
#         83, 119,  93, 105,  99,  77,  92, 108, 115,  68,  61, 106, 102,
#         94,  66,  76,  62,  96, 113,  67,  88, 112, 104,  71,  72,  98,
#        101,  64, 103, 114, 111, 107])

# %%
df["ap_lo"].value_counts()
# Out:
# ap_lo
# 80     34725
# 90     14239
# 70     10212
# 100     3978
# 60      2656
# 79       357
# 110      338
# 85       290
# 75       209
# 95       158
# 120      134
# 89       122
# 69        98
# 65        78
# 82        33
# 84        32
# 83        30
# 87        29
# 78        27
# 74        26
# 86        26
# 73        22
# 72        22
# 92        21
# 81        21
# 91        20
# 88        20
# 99        20
# 76        19
# 67        19
# 77        18
# 94        17
# 105       17
# 98        16
# 96        14
# 71        14
# 97        13
# 68        13
# 93        11
# 66        11
# 64        10
# 63         7
# 62         7
# 115        7
# 109        6
# 103        6
# 61         6
# 101        5
# 104        5
# 106        5
# 102        4
# 108        3
# 113        3
# 119        2
# 112        1
# 114        1
# 111        1
# 107        1
# Name: count, dtype: int64

# %% [markdown]
# ### cholesterol

# %%
df["cholesterol"].unique()
# Out:
# array([1, 3, 2])

# %%
df["cholesterol"].value_counts()
# Out:
# cholesterol
# 1    51222
# 2     9191
# 3     7792
# Name: count, dtype: int64

# %% [markdown]
# ### Gluc (glucose level )

# %%
df["gluc"].unique()
# Out:
# array([1, 2, 3])

# %%
df["gluc"].value_counts()
# Out:
# gluc
# 1    58027
# 3     5180
# 2     4998
# Name: count, dtype: int64

# %% [markdown]
# ### smoke

# %%
df["smoke"].unique()
# Out:
# array([0, 1])

# %%
df["smoke"].value_counts()
# Out:
# smoke
# 0    62226
# 1     5979
# Name: count, dtype: int64

# %% [markdown]
# ### alco

# %%
df["alco"].unique()
# Out:
# array([0, 1])

# %%
df["alco"].value_counts()
# Out:
# alco
# 0    64581
# 1     3624
# Name: count, dtype: int64

# %% [markdown]
# ### active

# %%
df["active"].unique()
# Out:
# array([1, 0])

# %%
df["active"].value_counts()
# Out:
# active
# 1    54806
# 0    13399
# Name: count, dtype: int64

# %% [markdown]
# ### cardio

# %%
df['cardio'].unique()
# Out:
# array([0, 1])

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    34533
# 1    33672
# Name: count, dtype: int64

# %%
df.drop('cardio',  axis = 1 , inplace= True )

# %% [markdown]
# ### Age

# %%
df['age_years'].unique()
# Out:
# array([50, 55, 51, 48, 47, 60, 61, 54, 40, 39, 45, 58, 59, 63, 64, 53, 49,
#        57, 56, 46, 43, 62, 52, 42, 44, 41, 29, 30])

# %%
df.rename( columns  =  {'age_years':'age' } , inplace=True)

# %%
df.head()
# Out:
#   gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0      M     168    62.0    110     80            1     1      0     0
# 1      F     156    85.0    140     90            3     1      0     0
# 2      F     165    64.0    130     70            3     1      0     0
# 3      M     169    82.0    150    100            1     1      0     0
# 4      F     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age        bmi           bp_category   bp_category_encoded
# 0       1       0   50  21.967120  Hypertension Stage 1  Hypertension Stage 1
# 1       1       1   55  34.927679  Hypertension Stage 2  Hypertension Stage 2
# 2       0       1   51  23.507805  Hypertension Stage 1  Hypertension Stage 1
# 3       1       1   48  28.710479  Hypertension Stage 2  Hypertension Stage 2
# 4       0       0   47  23.011177                Normal                Normal

# %% [markdown]
# ### bmi

# %%
df['bmi'].unique()
# Out:
# array([21.96712018, 34.92767916, 23.50780533, ..., 19.23018223,
#        29.19412649, 50.47268066], shape=(3752,))

# %%
df['bmi'].value_counts()
# Out:
# bmi
# 23.875115    930
# 23.437500    641
# 24.221453    485
# 25.711662    359
# 22.038567    354
#             ...
# 55.096419      1
# 47.417660      1
# 52.073001      1
# 32.215630      1
# 42.790865      1
# Name: count, Length: 3752, dtype: int64

# %%
df['bmi'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# bp category

# %%
df['bp_category'].value_counts()
# Out:
# bp_category
# Hypertension Stage 1    39750
# Hypertension Stage 2    15937
# Normal                   9417
# Elevated                 3101
# Name: count, dtype: int64

# %%
df
# Out:
#       gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0          M     168    62.0    110     80            1     1      0     0
# 1          F     156    85.0    140     90            3     1      0     0
# 2          F     165    64.0    130     70            3     1      0     0
# 3          M     169    82.0    150    100            1     1      0     0
# 4          F     156    56.0    100     60            1     1      0     0
# ...      ...     ...     ...    ...    ...          ...   ...    ...   ...
# 68200      M     168    76.0    120     80            1     1      1     0
# 68201      F     158   126.0    140     90            2     2      0     0
# 68202      M     183   105.0    180     90            3     1      0     1
# 68203      F     163    72.0    135     80            1     2      0     0
# 68204      F     170    72.0    120     80            2     1      0     0
#
#        active  cardio  age        bmi           bp_category
# ...

# %% [markdown]
# ### bp_category_encoded

# %%
df.drop(['bp_category_encoded'] ,  axis=1 , inplace = True)

# %%
df.head()
# Out:
#   gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0      M     168    62.0    110     80            1     1      0     0
# 1      F     156    85.0    140     90            3     1      0     0
# 2      F     165    64.0    130     70            3     1      0     0
# 3      M     169    82.0    150    100            1     1      0     0
# 4      F     156    56.0    100     60            1     1      0     0
#
#    active  age        bmi           bp_category
# 0       1   50  21.967120  Hypertension Stage 1
# 1       1   55  34.927679  Hypertension Stage 2
# 2       0   51  23.507805  Hypertension Stage 1
# 3       1   48  28.710479  Hypertension Stage 2
# 4       0   47  23.011177                Normal

# %% [markdown]
# save new data

# %%
df.to_csv("../../data/hyper.csv" ,  index=False)

# %% [markdown]
# ### Load the data

# %%
p_df = pd.read_csv("../../data/hyper.csv")

# %%
p_df.head()
# Out:
#   gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0      M     168    62.0    110     80            1     1      0     0
# 1      F     156    85.0    140     90            3     1      0     0
# 2      F     165    64.0    130     70            3     1      0     0
# 3      M     169    82.0    150    100            1     1      0     0
# 4      F     156    56.0    100     60            1     1      0     0
#
#    active  age        bmi           bp_category
# 0       1   50  21.967120  Hypertension Stage 1
# 1       1   55  34.927679  Hypertension Stage 2
# 2       0   51  23.507805  Hypertension Stage 1
# 3       1   48  28.710479  Hypertension Stage 2
# 4       0   47  23.011177                Normal
